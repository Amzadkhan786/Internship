# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('https://raw.githubusercontent.com/FlipRoboTechnologies/ML-Datasets/main/Grades/Grades.csv')
df
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 0    CS-97001     B-     D+     C-         C     C-     D+      D     C-
# 1    CS-97002      A      D     D+         D     B-      C      D      A
# 2    CS-97003      A      B      A        B-     B+      A     B-     B+
# 3    CS-97004      D     C+     D+         D      D     A-     D+     C-
# 4    CS-97005     A-     A-     A-        B+      A      A     A-     B+
# ..        ...    ...    ...    ...       ...    ...    ...    ...    ...
# 566  CS-97567      B      A      A        A-     A+      A     A-     A-
# 567  CS-97568     A+      A      A         A      A      A      A     A-
# 568  CS-97569      B      A     A-        B+      A      A      A      A
# 569  CS-97570      A     B+      D         A      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
#     EE-119  ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 43 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Seat No.   571 non-null    object
#  1   PH-121     571 non-null    object
#  2   HS-101     571 non-null    object
#  3   CY-105     570 non-null    object
#  4   HS-105/12  570 non-null    object
#  5   MT-111     569 non-null    object
#  6   CS-105     571 non-null    object
#  7   CS-106     569 non-null    object
#  8   EL-102     569 non-null    object
#  9   EE-119     569 non-null    object
#  10  ME-107     569 non-null    object
#  11  CS-107     569 non-null    object
#  12  HS-205/20  566 non-null    object
#  13  MT-222     566 non-null    object
#  14  EE-222     564 non-null    object
#  15  MT-224     564 non-null    object
#  16  CS-210     564 non-null    object
#  17  CS-211     566 non-null    object
#  18  CS-203     566 non-null    object
# ...

# %%
len(df)
# Out:
# 571

# %%
for i in df.columns:
    if len(i) < len(df):
        df[i] = df[i].fillna(df[i].mode()[0])
df.isnull().sum()
# Out:
# Seat No.     0
# PH-121       0
# HS-101       0
# CY-105       0
# HS-105/12    0
# MT-111       0
# CS-105       0
# CS-106       0
# EL-102       0
# EE-119       0
# ME-107       0
# CS-107       0
# HS-205/20    0
# MT-222       0
# EE-222       0
# MT-224       0
# CS-210       0
# CS-211       0
# CS-203       0
# CS-214       0
# EE-217       0
# CS-212       0
# CS-215       0
# MT-331       0
# EF-303       0
# HS-304       0
# CS-301       0
# CS-302       0
# TC-383       0
# MT-442       0
# EL-332       0
# CS-318       0
# CS-306       0
# CS-312       0
# CS-317       0
# CS-403       0
# CS-421       0
# CS-406       0
# CS-414       0
# CS-419       0
# CS-423       0
# CS-412       0
# CGPA         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 43 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Seat No.   571 non-null    object
#  1   PH-121     571 non-null    object
#  2   HS-101     571 non-null    object
#  3   CY-105     571 non-null    object
#  4   HS-105/12  571 non-null    object
#  5   MT-111     571 non-null    object
#  6   CS-105     571 non-null    object
#  7   CS-106     571 non-null    object
#  8   EL-102     571 non-null    object
#  9   EE-119     571 non-null    object
#  10  ME-107     571 non-null    object
#  11  CS-107     571 non-null    object
#  12  HS-205/20  571 non-null    object
#  13  MT-222     571 non-null    object
#  14  EE-222     571 non-null    object
#  15  MT-224     571 non-null    object
#  16  CS-210     571 non-null    object
#  17  CS-211     571 non-null    object
#  18  CS-203     571 non-null    object
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for i in df.columns:
    if i != 'CGPA' and 'Seat No.':
        df[i] = le.fit_transform(df[i])
df
# Out:
#      Seat No.  PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  \
# 0           0       5      10       8          6       8      10       9
# 1           1       0       9      10          9       5       6       9
# 2           2       0       3       0          5       4       0       5
# 3           3       9       7      10          9       9       2      10
# 4           4       2       2       2          4       0       0       2
# ..        ...     ...     ...     ...        ...     ...     ...     ...
# 566       566       3       0       0          2       1       0       2
# 567       567       1       0       0          0       0       0       0
# 568       568       3       0       2          4       0       0       0
# 569       569       0       4       9          0       9      10       5
# 570       570       6       9       9          6       6      10       3
#
#      EL-102  EE-119  ...  CS-312  CS-317  CS-403  CS-421  CS-406  CS-414  \
# ...

# %%
plt.figure(figsize = (20,25), facecolor = "red")
plot_number = 1

for column in df:
    if plot_number<=len(df.columns):
        ax = plt.subplot(9,5,plot_number)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize = 15)
    
    plot_number +=1
plt.show()

# %%
plt.figure(figsize = (20,25), facecolor = "red")
plot_number = 1

for column in df:
    if plot_number<=len(df.columns):
        ax = plt.subplot(9,5,plot_number)
        sns.boxplot(df[column])
        plt.xlabel(column,fontsize = 15)
    
    plot_number +=1
plt.show()

# %%
df.skew()
# Out:
# Seat No.     0.000000
# PH-121       0.549104
# HS-101       0.053303
# CY-105       0.982144
# HS-105/12    0.324183
# MT-111       0.484906
# CS-105       0.930769
# CS-106       0.639845
# EL-102       0.501161
# EE-119       0.574880
# ME-107       0.108385
# CS-107       0.414846
# HS-205/20    0.897186
# MT-222       0.193993
# EE-222       0.759105
# MT-224       0.430480
# CS-210       0.723967
# CS-211       0.116085
# CS-203       0.274205
# CS-214       0.013129
# EE-217       0.724325
# CS-212       0.414872
# CS-215       0.163631
# MT-331       0.627721
# EF-303       0.383655
# HS-304       0.544843
# CS-301       0.415084
# CS-302       0.601788
# TC-383       0.331652
# MT-442       0.869952
# EL-332       0.459160
# CS-318       0.356504
# CS-306       0.424753
# CS-312       0.442525
# CS-317       0.140692
# CS-403       0.618339
# CS-421       0.179508
# CS-406       1.522703
# CS-414       1.292931
# CS-419       0.506748
# CS-423       0.526550
# ...

# %%
#Check z_score values to reduce skewness and convert the data in more efficient manner

from scipy.stats import zscore
z_score = zscore(df[["CY-105","CS-105","CS-406","CS-414","CS-412"]])
abs_z_score = np.abs(z_score)
filtering = (abs_z_score <3).all(axis = 1)
df = df[filtering]

df.describe()
# Out:
#          Seat No.      PH-121      HS-101      CY-105   HS-105/12      MT-111  \
# count  545.000000  545.000000  545.000000  545.000000  545.000000  545.000000
# mean   278.086239    3.669725    4.970642    2.822018    4.133945    3.770642
# std    163.204789    3.026401    2.737784    2.878590    3.149820    2.928163
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%    138.000000    2.000000    3.000000    0.000000    2.000000    2.000000
# 50%    275.000000    3.000000    5.000000    2.000000    4.000000    3.000000
# 75%    416.000000    6.000000    7.000000    4.000000    7.000000    6.000000
# max    569.000000   12.000000   11.000000   11.000000   11.000000   12.000000
#
#            CS-105      CS-106      EL-102      EE-119  ...      CS-312  \
# count  545.000000  545.000000  545.000000  545.000000  ...  545.000000
# mean     2.746789    4.038532    3.829358    3.788991  ...    3.970642
# ...

# %%
df.skew()
# Out:
# Seat No.     0.047296
# PH-121       0.612258
# HS-101       0.081020
# CY-105       0.959983
# HS-105/12    0.333861
# MT-111       0.500520
# CS-105       0.976091
# CS-106       0.621221
# EL-102       0.530990
# EE-119       0.623851
# ME-107       0.130936
# CS-107       0.430743
# HS-205/20    0.875818
# MT-222       0.201565
# EE-222       0.771351
# MT-224       0.466658
# CS-210       0.744494
# CS-211       0.106898
# CS-203       0.295745
# CS-214       0.034597
# EE-217       0.751424
# CS-212       0.419931
# CS-215       0.184192
# MT-331       0.673974
# EF-303       0.365058
# HS-304       0.453271
# CS-301       0.427313
# CS-302       0.625156
# TC-383       0.375839
# MT-442       0.878068
# EL-332       0.454847
# CS-318       0.349148
# CS-306       0.434348
# CS-312       0.455297
# CS-317       0.143278
# CS-403       0.608690
# CS-421       0.118263
# CS-406       1.358122
# CS-414       0.890764
# CS-419       0.488111
# CS-423       0.507667
# ...

# %%
plt.figure(figsize = (20,25), facecolor = "red")
plot_number = 1

for column in df:
    if plot_number<=len(df.columns):
        ax = plt.subplot(9,5,plot_number)
        sns.boxplot(df[column])
        plt.xlabel(column,fontsize = 15)
    
    plot_number +=1
plt.show()

# %%
df['CGPA'].info
# Out:
# <bound method Series.info of 0      2.205
# 1      2.008
# 2      3.608
# 3      1.906
# 4      3.448
#        ...
# 565    0.800
# 566    3.798
# 567    3.772
# 568    3.470
# 569    2.193
# Name: CGPA, Length: 545, dtype: float64>

# %%
y = df['CGPA']
X = df.drop(columns = ['CGPA','Seat No.'])

# %%
#Visaulization

plt.figure(figsize =(20,30), facecolor = 'yellow')
plotnumber = 1

for column in X:
    if plotnumber <=len(df.columns):
        plt.subplot(11,4,plotnumber)
        plt.scatter(X[column],y)
        plt.xlabel(column,fontsize = 10)
        plt.ylabel('CGPA',fontsize = 10)
    
    plotnumber +=1

#plt.show()
plt.tight_layout()

# %%
#Data Scaling . Formula Z (X -Mean)/S.T.D
from sklearn.preprocessing import StandardScaler
scaler =StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error,r2_score
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor

# %%
#Linear Regression
#Iterate random state for select best data for train the model and enhance accuracy

Max_accuracy = 0
Max_random_s = 0
for i in range(1,500):
    x_train,x_test,y_train,y_test = train_test_split(X_scaled,y, train_size = 0.70, random_state = i)
    lr = LinearRegression()
    lr.fit(x_train,y_train)
    y_pred = lr.predict(x_test)
    accuracy = r2_score(y_test,y_pred)
    if accuracy>Max_accuracy:
        Max_accuracy = accuracy
        Max_random_s = i
print("Best Accuracy:-",Max_accuracy,"At This Ramdon State:-",Max_random_s)
# Out:
# Best Accuracy:- 0.969032378265782 At This Ramdon State:- 344

# %%
#Random Forest
#Iterate random state for select best data for train the model and enhance accuracy

Max_accuracy = 0
Max_random_s = 0
for i in range(1,100):
    x_train,x_test,y_train,y_test = train_test_split(X_scaled,y, train_size = 0.70, random_state = i)
    rfr = RandomForestRegressor()
    rfr.fit(x_train,y_train)
    y_pred = rfr.predict(x_test)
    accuracy = r2_score(y_test,y_pred)
    if accuracy>Max_accuracy:
        Max_accuracy = accuracy
        Max_random_s = i
print("Best Accuracy:-",Max_accuracy,"At This Ramdon State:-",Max_random_s)
# Out:
# Best Accuracy:- 0.9671606005846138 At This Ramdon State:- 9

# %%
x_train,x_test,y_train,y_test = train_test_split(X_scaled,y, train_size = 0.70, random_state = 344)

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)
pred = lr.predict(x_test)
pred_t = lr.predict(x_train)
print("R2_Score",r2_score(y_test,pred))
print("r2_Score On Training Data", r2_score(y_train,pred_t))
# Out:
# R2_Score 0.969032378265782
# r2_Score On Training Data 0.9124256175160406

# %%
print('Mean Absolute Error',mean_absolute_error(y_test,pred))
print("Mean Squared Error",mean_squared_error(y_test,pred))
print("Root Mean Squared Error",np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# Mean Absolute Error 0.08463157424765158
# Mean Squared Error 0.011900290398440514
# Root Mean Squared Error 0.10908845217730662

# %%
from sklearn.linear_model import Ridge,Lasso,RidgeCV,LassoCV
lasscv = LassoCV(alphas = None, max_iter = 10)
lasscv.fit(x_train,y_train)
#Best Alpha Parameters
alpha=lasscv.alpha_
alpha
# Out:
# 0.009732185543856575

# %%
lasso_reg = Lasso(alpha)
lasso_reg.fit(x_train,y_train)
# Out:
# Lasso(alpha=0.009732185543856575)

# %%
lasso_reg.score(x_test,y_test)
# Out:
# 0.969548305364523

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('https://raw.githubusercontent.com/FlipRoboTechnologies/ML-Datasets/main/World%20Happiness/happiness_score_dataset.csv')
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
df.Region.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0                       Western Europe
# 1                       Western Europe
# 2                       Western Europe
# 3                       Western Europe
# 4                        North America
#                     ...
# 153                 Sub-Saharan Africa
# 154                 Sub-Saharan Africa
# 155    Middle East and Northern Africa
# 156                 Sub-Saharan Africa
# 157                 Sub-Saharan Africa
# Name: Region, Length: 158, dtype: object>

# %%
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()
df['Country'] = lb.fit_transform(df['Country'])
df['Region'] = lb.fit_transform(df['Region'])

# %%
df
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0        135       9               1            7.587         0.03411
# 1         58       9               2            7.561         0.04884
# 2         37       9               3            7.527         0.03328
# 3        105       9               4            7.522         0.03880
# 4         24       5               5            7.427         0.03553
# ..       ...     ...             ...              ...             ...
# 153      118       8             154            3.465         0.03464
# 154       13       8             155            3.340         0.03656
# 155      136       4             156            3.006         0.05015
# 156       21       8             157            2.905         0.08658
# 157      141       8             158            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
#Use Heatmap To Check Correlation
df_corr = df.corr().abs()
plt.figure(figsize = (15,10))
sns.heatmap(df_corr,annot = True,annot_kws={"size":10})
# Out:
# <Axes: >

# %%
X = df.iloc[:, [0,1,4,8,9,10,11]]
y = df.iloc[:, 3]

# %%
X
# Out:
#      Country  Region  Standard Error  Freedom  Trust (Government Corruption)  \
# 0        135       9         0.03411  0.66557                        0.41978
# 1         58       9         0.04884  0.62877                        0.14145
# 2         37       9         0.03328  0.64938                        0.48357
# 3        105       9         0.03880  0.66973                        0.36503
# 4         24       5         0.03553  0.63297                        0.32957
# ..       ...     ...             ...      ...                            ...
# 153      118       8         0.03464  0.59201                        0.55191
# 154       13       8         0.03656  0.48450                        0.08010
# 155      136       4         0.05015  0.15684                        0.18906
# 156       21       8         0.08658  0.11850                        0.10062
# 157      141       8         0.06727  0.36453                        0.10731
#
#      Generosity  Dystopia Residual
# ...

# %%
y
# Out:
# 0      7.587
# 1      7.561
# 2      7.527
# 3      7.522
# 4      7.427
#        ...
# 153    3.465
# 154    3.340
# 155    3.006
# 156    2.905
# 157    2.839
# Name: Happiness Score, Length: 158, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
from math import sqrt
Max_score = 0
Max_random_s = 0
scaler= StandardScaler()
X = scaler.fit_transform(X)
for i in range(0, 501):
    x_train,x_test,y_train,y_test = train_test_split(X,y,test_size = 0.20, random_state=i)
    regression = LinearRegression()
    regression.fit(x_train,y_train)
    y_pred = regression.predict(x_test)
    score = regression.score(x_test,y_test)
    if score>Max_score:
        Max_score = score
        Max_random_s = i
print("Best Accuracy:-",Max_score,"At This Ramdon State:-",Max_random_s)
# Out:
# Best Accuracy:- 0.8361396918309008 At This Ramdon State:- 438

# %%
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size = 0.20, random_state=438)

# %%
regression = LinearRegression()
regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = regression.predict(x_test)
score = regression.score(x_test,y_test)

# %%
regression.score(x_train,y_train)
# Out:
# 0.6203605748670544

# %%
regression.score(x_test,y_test)
# Out:
# 0.8361396918309008
